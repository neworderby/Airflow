# %% [markdown]
# <a href="https://colab.research.google.com/github/neworderby/Airflow/blob/main/Airflow_in_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Установка Airflow
# !pip install 'apache-airflow[google,amazon,postgres]'==2.1.4 #[all]/[all_dbs]

# Установка HTTP провайдера и телеграм провайдера
# !pip install apache-airflow-providers-http
# !pip install apache-airflow-providers-telegram

# Инициализация базы данных
# !airflow db init
# Out:
# ...
#   Using cached apache_airflow-2.1.4-py3-none-any.whl.metadata (91 kB)
# ...
#   Using cached attrs-20.3.0-py2.py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached colorlog-5.0.1-py2.py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached croniter-1.0.15-py2.py3-none-any.whl.metadata (21 kB)
# ...
#   Using cached Flask-1.1.4-py2.py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached Flask_AppBuilder-3.4.5-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached Flask_Caching-1.11.1-py3-none-any.whl.metadata (2.2 kB)
# ...
#   Using cached Flask_Login-0.4.1-py2.py3-none-any.whl
# ...
#   Using cached Flask_WTF-0.14.3-py2.py3-none-any.whl.metadata (2.0 kB)
# ...
#   Using cached itsdangerous-1.1.0-py2.py3-none-any.whl.metadata (3.1 kB)
# ...
#   Using cached jsonschema-3.2.0-py2.py3-none-any.whl.metadata (7.8 kB)
# ...
#   Using cached MarkupSafe-1.1.1-cp311-cp311-linux_x86_64.whl
# ...
#   Using cached PyJWT-1.7.1-py2.py3-none-any.whl.metadata (3.9 kB)
# ...
#   Using cached python_slugify-4.0.1-py2.py3-none-any.whl
# ...

# %%
# Создадим необходимые папки
# !mkdir /root/airflow/dags
# !touch /root/airflow/dags/dag.py

# %%
# Создадим пользователя Airflow
# !airflow users create \
          --username admin \
          --firstname admin \
          --lastname admin \
          --role Admin \
          --email admin@example.org \
          -p 12345
# Out:
# /usr/local/lib/python3.11/dist-packages/flask_limiter/extension.py:333 UserWarning: Using the in-memory storage for tracking rate limits as no storage was explicitly specified. This is not recommended for production use. See: https://flask-limiter.readthedocs.io#configuring-a-storage-backend for documentation about configuring the storage backend.
# [2025-02-16T15:14:28.959+0000] {override.py:1526} INFO - Inserted Role: Admin
# [2025-02-16T15:14:28.963+0000] {override.py:983} WARNING - No user yet created, use flask fab command to do it.
# [2025-02-16T15:14:29.048+0000] {override.py:1930} INFO - Created Permission View: can edit on Passwords
# [2025-02-16T15:14:29.062+0000] {override.py:1981} INFO - Added Permission can edit on Passwords to role Admin
# [2025-02-16T15:14:29.087+0000] {override.py:1930} INFO - Created Permission View: can read on Passwords
# [2025-02-16T15:14:29.100+0000] {override.py:1981} INFO - Added Permission can read on Passwords to role Admin
# ...

# %%
# Включим веб-сервер
# !airflow webserver -p 18273 -D
# Out:
# [2025-02-16T15:14:40.477+0000] {configuration.py:2112} INFO - Creating new FAB webserver config file in: /root/airflow/webserver_config.py
#   ____________       _____________
#  ____    |__( )_________  __/__  /________      __
# ____  /| |_  /__  ___/_  /_ __  /_  __ \_ | /| / /
# ___  ___ |  / _  /   _  __/ _  / / /_/ /_ |/ |/ /
#  _/_/  |_/_/  /_/    /_/    /_/  \____/____/|__/
# Running the Gunicorn Server with:
# Workers: 4 sync
# Host: 0.0.0.0:18273
# Timeout: 120
# Logfiles: - -
# Access Logformat:
# ...
# [2025-02-16T15:14:40.786+0000] {dagbag.py:588} INFO - Filling up the DagBag from /dev/null
# /usr/local/lib/python3.11/dist-packages/flask_limiter/extension.py:333 UserWarning: Using the in-memory storage for tracking rate limits as no storage was explicitly specified. This is not recommended for production use. See: https://flask-limiter.readthedocs.io#configuring-a-storage-backend for documentation about configuring the storage backend.
# ...

# %%
# Запуск шедулера
# !airflow scheduler -D
# Out:
#   ____________       _____________
#  ____    |__( )_________  __/__  /________      __
# ____  /| |_  /__  ___/_  /_ __  /_  __ \_ | /| / /
# ___  ___ |  / _  /   _  __/ _  / / /_/ /_ |/ |/ /
#  _/_/  |_/_/  /_/    /_/    /_/  \____/____/|__/
